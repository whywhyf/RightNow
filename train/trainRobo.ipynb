# %%
# !nvidia-smi
# Out:
# Sun Jul 16 00:26:25 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.40                 Driver Version: 536.40       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 2060      WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   47C    P8              11W /  80W |    639MiB /  6144MiB |     27%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\HP\Desktop\things\offterm\court\train

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20  Python-3.9.13 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# Setup complete  (12 CPUs, 15.8 GB RAM, 243.8/248.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

# from roboflow import Roboflow
# rf = Roboflow(api_key="JWxOLLw6YEwiNTZ9CuQU")
# project = rf.workspace("mytem").project("baskeball")
# dataset = project.version(1).download("yolov8")

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JWxOLLw6YEwiNTZ9CuQU")
project = rf.workspace("yyf").project("ball-detector-y6tgg")
dataset = project.version(2).download("yolov8")
# Out:
# �����﷨����ȷ��
# c:\Users\HP\Desktop\things\offterm\court\train\datasets
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ball-detector-2 in yolov8:: 100%|██████████| 6380/6380 [00:03<00:00, 1955.98it/s]

# %%
print(dataset.location)
# Out:
# c:\Users\HP\Desktop\things\offterm\court\train\datasets\ball-detector-2

# %%
# !pip install ultralytics<=8.0.20
# Out:
# ϵͳ�Ҳ���ָ�����ļ���

# %%
import torch

print(torch.__version__) # pytorch版本
print(torch.version.cuda) # cuda版本
print(torch.cuda.is_available()) # 查看cuda是否可用

#crtl+z 回车  退出python环境
# Out:
# 2.0.1+cu118
# 11.8
# True

# %%
# # 使用CPU：
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1" # 这一行注释掉就是使用cpu，不注释就是使用gpu
 
# 使用GPU：
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ['CUDA_VISIBLE_DEVICES'] = "0" #这个是仅选择使用GPU 0
# os.environ['CUDA_VISIBLE_DEVICES'] = "1" #这个是仅选择使用GPU 1
# os.environ['CUDA_VISIBLE_DEVICES']  = “0,1” #设置当前使用的GPU设备为0,1号

# %%
# !tensorboard --logdir=runs
# Out:
# 'tensorboard' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
# import tensorboard

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=1 imgsz=640 plots=True
# !yolo task=detect mode=train model=yolov8n.pt data=c:/Users/HP/Desktop/things/offterm/court/train/datasets/ball-detector-2/data.yaml epochs=200 imgsz=640 plots=True batch=16
# Out:
# c:\Users\HP\Desktop\things\offterm\court\train
# Ultralytics YOLOv8.0.134  Python-3.9.13 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...
